# %%
import time
import random

name = input("Hello, what is your name?")

time.sleep(2)
print("Hello " + name)

feeling = input("How are you today? ")

time.sleep(2)
if "good" in feeling:
    print("I'm feeling good too!")
else:
    print("I'm sorry to hear that!")

time.sleep(2)
favcolour = input("What is your favourite colour? ")

colours = ["Red","Green","Blue"]

time.sleep(2)
print("My favourite colour is " + random.choice(colours))

fever = input("Do you have Fever? ")
time.sleep(2)
if "yes" in fever:
    print("I will measure your fever ")
else:
    print("Thats Good")
           
cold = input("Do you have cold? ")
time.sleep(2)
if "yes" in cold:
    print("OK ")
else:
    print("Thats Good")
    
headache = input("Do you have headache? ")
time.sleep(2)
if "yes" in headache:
    print("I will note that ")
else:
    print("Thats Good")
    
time.sleep(2)
favfood = input("What is your favourite food? ")

food = ["Tacos","Burger","Pizza"]

time.sleep(2)
print("My favourite food is " + random.choice(food)+"!")

pain= input("Do you have pain in your body? ")

time.sleep(2)
if "yes" in pain:
    print("Okay I will note that too!")

else:    
    print("Thats Really good!")
    
    exercise= input("DO you exercie regularly,Sometimes or Not at all? ")

time.sleep(3)
if "regularly" in exercise:
    print("Thats good for your health!")
else:    
    print("Exercising regularly or sometimes can help you from various diseases")
    
    
        
meet= input("Its good to meet you and I will forward your information to higher authorities  ")
time.sleep(3)
if "ok" in meet:
    print("Thank you")
elif "thank you":
    print("You're Welcome")
else:    
    print("Good Bye")
# Out:
# Hello, what is your name?AMAN
# Hello AMAN
# How are you today? not fine
# I'm sorry to hear that!
# What is your favourite colour? red
# My favourite colour is Red
# Do you have Fever? yes
# I will measure your fever
# Do you have cold? yes
# OK
# Do you have headache? no
# Thats Good
# What is your favourite food? pizza
# My favourite food is Pizza!
# Do you have pain in your body? no
# Thats Really good!
# DO you exercie regularly,Sometimes or Not at all? regularly
# Thats good for your health!
# Its good to meet you and I will forward your information to higher authorities  thank you
# You're Welcome
